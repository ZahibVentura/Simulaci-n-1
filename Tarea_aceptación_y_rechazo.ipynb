# %% [markdown]
# <a href="https://colab.research.google.com/github/ZahibVentura/Simulaci-n-1/blob/main/Tarea_aceptaci%C3%B3n_y_rechazo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random as rd
import matplotlib.pyplot as plt   #importamos todas las librerias a utilizar
import numpy as np

# %%
#La siguiente parte del codigo grafica la función la cual se intenta simular

#Puesto que es una funcion a trozos se define el intervalo 4<=X<5 de para la primera parte de la función
a = 4
b = 5
X = np.linspace(a, b, 50)
Y = (11-2*X)/4   #primer trozo de la función

c = 5   #intervalo 5<=X<=6
d = 6
V = np.linspace(c,d, 50)
W = (2*V - 9)/4  #segundo trozo de la función

x = [4,5,6]
y = [0.75,0.25,0.75]

plt.figure()

for i in range(len(x)):
    plt.text(x[i], y[i], f'({x[i]}, {y[i]})') #se muestran los puntos donde hay la intersección de las funciones y extremos

plt.plot(X, Y, 'k')   #se grafican ambas funciones por partes (son dos partes)
plt.plot(V, W, 'k')
plt.xlabel('Eje X')
plt.ylabel('Eje Y')  #titulos de ejes
plt.grid()
plt.show()

# %%
#La siguiente parte del codigo grafica la función acumulativa

X = np.linspace(a, b, 50)
Y = (-X**2-28+11*X)/4     #esta es la función acumulativa del primer trozo de la función

V = np.linspace(c,d, 50)
W = 0.5 + (V**2 - 9*V + 20)/4   #esta es la función acumulativa del segundo trozo de la función

x = [4,5,6]
y = [0,0.5,1]

plt.figure()

for i in range(len(x)):
    plt.text(x[i], y[i], f'({x[i]}, {y[i]})')  #se muestran los puntos donde hay la intersección de las funciones acumulativas y extremos

plt.plot(X, Y, 'k')
plt.plot(V, W, 'k')  #se grafican ambas funciones acumulativas por partes (son dos partes)
plt.xlabel('Eje X')
plt.ylabel('Eje Y')  #titulos a los ejes
plt.grid()
plt.show()

# %%
#La función de la grafica es una f.d.p
#Se comprobó que la integral total da como resultado 1
#además la función siempre es positiva para todo X en el intervalo [4,6]
#se aplica el método de la aceptación y rechazo para su simulación
#tomando a c = 2 y g(x)= 1/2

#El siguiente código muestra la simulación de dicha función

def funcion(N=50): #Definimos una función que regresa una lista de valores x
  Lista = []
  for i in range(N):
    u = rd.uniform(0,1) #variable uniforme de 0 a 1
    y = rd.uniform(4,6) #variable uniforme de 4 a 6
    if y <= 5:
      f = (11 - 2*y)/4
    else:
      f = (2*y -9)/4

    if u <= f: #condicion para regresar x
      x = y
      Lista.append(x)
  return Lista # se regresa la lista

# %%
F = funcion(100000) #se manda a llamar a la función con 100000 iteraciones

# %%
plt.hist(F,bins = 100)   #mostramos el histograma
plt.show()
